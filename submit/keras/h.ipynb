# %%
import pickle

pickle_name = 'history.pickle'

with open(pickle_name,"rb") as fr:
    data = pickle.load(fr)
    
with open('test_acc_listkeras_CNN_ReLU__iters_num=10000__batchSize_400__learning_rate_0.01__HIDDEN_SIZE =50.pickle',"rb") as fr:
    test = pickle.load(fr)
    
with open('train_acc_listkeras_CNN_ReLU__iters_num=10000__batchSize_400__learning_rate_0.01__HIDDEN_SIZE =50.pickle',"rb") as fr:
    train = pickle.load(fr)
# Out:
# Metal device set to: Apple M1 Pro
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2022-11-28 10:19:52.288300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-11-28 10:19:52.288427: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import matplotlib.pyplot as plt
import numpy as np
# 그래프 그리기
markers = {'train': 'o', 'test': 's'}
x = np.arange(20)
train = np.array(train)
print(train)
#ploting 하기
plt.plot(x, train[0], marker='o', label='train', markevery=2)
plt.plot(x, test[0], marker='s', label='test', markevery=2)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# [[0.40170002 0.54522002 0.59582001 0.63636005 0.66764003 0.69110006
#   0.71186006 0.73478007 0.75360006 0.76910007 0.78824008 0.81040007
#   0.82370007 0.84320003 0.86040008 0.87466007 0.89450008 0.90480006
#   0.91780007 0.93396008]]
